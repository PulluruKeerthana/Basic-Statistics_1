# %%
import pandas as pd
import scipy
from scipy import stats

# %%
df = pd.read_csv("Q9_b.csv")

# %%
df
# Out:
#     Unnamed: 0          SP         WT
# 0            1  104.185353  28.762059
# 1            2  105.461264  30.466833
# 2            3  105.461264  30.193597
# 3            4  113.461264  30.632114
# 4            5  104.461264  29.889149
# ..         ...         ...        ...
# 76          77  169.598513  16.132947
# 77          78  150.576579  37.923113
# 78          79  151.598513  15.769625
# 79          80  167.944460  39.423099
# 80          81  139.840817  34.948615
#
# [81 rows x 3 columns]

# %%
scipy.stats.skew(df,axis=0,bias=True)
# Out:
# array([ 0.        ,  1.58145368, -0.60330993])

# %%
scipy.stats.kurtosis(df, axis = 0, fisher = True, bias = True)
# Out:
# array([-1.20036585,  2.72352149,  0.81946588])

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["SP"])
plt.show()
#it is positive skewness

# %%
plt.hist(df["WT"])
plt.show()
#it is negitive skewness

# %%
plt.boxplot(df["SP"])
plt.show()
#there are outliers present above the upper bound

# %%
plt.boxplot(df["WT"])
plt.show()
#there are few outliers above upper bound and below lower bound
